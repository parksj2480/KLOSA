# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
df1=pd.read_csv("preprocessed_Lt01.csv")
df2=pd.read_csv("preprocessed_Lt02.csv")
df3=pd.read_csv("preprocessed_Lt03.csv")
df4=pd.read_csv("preprocessed_Lt04.csv")
df5=pd.read_csv("preprocessed_Lt05.csv")
df6=pd.read_csv("preprocessed_Lt06.csv")
df7=pd.read_csv("preprocessed_Lt07.csv")
df8=pd.read_csv("preprocessed_Lt08.csv")

# %%
pd.concat([df1,df2],axis=1).loc[0,:][['w01C107','w02C107']]
# Out:
# w01C107    152.0
# w02C107    150.0
# Name: 0, dtype: float64

# %%
# %matplotlib inline

scatter_matrix(df1.iloc[:,10:], figsize=(20, 20))
# Out:
# array([[<AxesSubplot:xlabel='w01chronic_b', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_c', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_d', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_e', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_f', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_g', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_h', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01chronic_i', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C056', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C081', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C082', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C085', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C105', ylabel='w01chronic_b'>,
#         <AxesSubplot:xlabel='w01C107', ylabel='w01chronic_b'>,
# ...

# %%
df1.plot(kind='scatter',y='w01mmse',x='w01bmi')
plt.title("Scatter plot of mmse vs bmi")
plt.show()
# Out:
# Text(0.5, 1.0, 'Scatter plot of mmse vs bmi')

# %%
df1.w01bmi.sort_values()
# Out:
# 706     -1250.000000
# 736     -1250.000000
# 724     -1250.000000
# 2479       -3.329865
# 5755       -3.245568
#             ...
# 5647       36.332180
# 3536       36.628512
# 4038       37.777778
# 726      9375.000000
# 725     10625.000000
# Name: w01bmi, Length: 10041, dtype: float64
